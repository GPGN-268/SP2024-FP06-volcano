# %%
import pandas as pd
import numpy as np
import cartopy
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
df = pd.read_csv('../data/sabancaya/seismic-data/query.csv')
df_ref = df[df['depth'] < 30]
df_ref
# Out:
#                          time  latitude  longitude   depth  mag magType  \
# 0    2024-02-26T01:40:31.794Z  -15.9980   -72.0610  10.000  4.1      mb
# 2    2023-12-10T16:10:55.405Z  -15.6591   -72.2564  11.469  4.0      mb
# 3    2023-10-31T22:13:49.191Z  -15.6045   -71.7692  10.000  4.5      mb
# 8    2023-06-06T17:53:22.213Z  -15.8589   -72.2625  10.000  4.4      mb
# 9    2023-06-05T13:25:15.423Z  -15.7861   -71.8108  10.000  4.3      mb
# ..                        ...       ...        ...     ...  ...     ...
# 118  2013-06-16T16:26:13.190Z  -15.7210   -71.8710   9.900  4.9      mb
# 122  2013-03-23T22:37:35.770Z  -15.8940   -71.8450  25.500  4.7      mb
# 126  2013-02-22T21:50:49.560Z  -15.8260   -71.4950  18.400  5.2      mb
# 127  2013-02-22T21:01:47.230Z  -15.7480   -71.4250   7.900  5.3      mb
# 137  2011-08-12T09:12:00.070Z  -15.7890   -71.9360  10.000  4.7      mb
#
#        nst    gap   dmin   rms  ...                   updated  \
# 0     21.0  178.0  2.875  0.66  ...  2024-03-12T22:43:11.040Z
# 2     12.0  128.0  3.260  1.18  ...  2024-02-17T22:43:05.040Z
# 3     39.0  134.0  2.952  0.85  ...  2024-01-18T21:11:05.637Z
# 8     38.0   92.0  3.100  0.61  ...  2023-08-12T17:15:05.040Z
# 9     30.0  133.0  2.865  0.86  ...  2023-08-12T17:15:03.040Z
# ..     ...    ...    ...   ...  ...                       ...
# 118   46.0   90.0    NaN  0.78  ...  2014-11-07T01:51:05.146Z
# 122   65.0   91.3    NaN  1.05  ...  2014-11-07T01:50:22.633Z
# 126  220.0   78.3    NaN  1.40  ...  2022-05-03T16:07:30.433Z
# 127  135.0   88.3    NaN  1.25  ...  2022-05-03T16:07:25.102Z
# 137   56.0  130.3    NaN  1.47  ...  2015-03-24T02:26:26.803Z
#
#                              place        type horizontalError depthError  \
# 0          5 km WNW of Lluta, Peru  earthquake           11.22      1.994
# 2             3 km NE of Ayo, Peru  earthquake           11.74      2.884
# 3             4 km N of Maca, Peru  earthquake           10.59      1.866
# 8             19 km S of Ayo, Peru  earthquake            8.78      1.263
# 9                    southern Peru  earthquake            7.96      1.593
# ..                             ...         ...             ...        ...
# 118         14 km SW of Maca, Peru  earthquake             NaN      1.700
# 122        22 km NE of Lluta, Peru  earthquake             NaN     14.200
# 126  7 km SSW of Huarancante, Peru  earthquake             NaN     16.600
# 127  4 km ENE of Huarancante, Peru  earthquake             NaN     14.100
# 137      19 km ESE of Huambo, Peru  earthquake             NaN        NaN
#
#      magError  magNst    status  locationSource magSource
# 0       0.123    18.0  reviewed              us        us
# 2       0.260     7.0  reviewed              us        us
# 3       0.088    38.0  reviewed              us        us
# 8       0.112    25.0  reviewed              us        us
# 9       0.188     8.0  reviewed              us        us
# ..        ...     ...       ...             ...       ...
# 118       NaN    28.0  reviewed              us        us
# 122       NaN    30.0  reviewed              us        us
# 126       NaN   157.0  reviewed              us        us
# 127       NaN    75.0  reviewed              us        us
# 137       NaN    34.0  reviewed              us        us
#
# [68 rows x 22 columns]

# %%
df_2012 = df_ref[df_ref['time'] < '2013']
df_2015 = df_ref[(df_ref['time'] > '2012') & (df_ref['time'] < '2016')]
df_2018 = df_ref[(df_ref['time'] > '2015') & (df_ref['time'] < '2019')]
df_2021 = df_ref[(df_ref['time'] > '2018') & (df_ref['time'] < '2022')]
df_2024 = df_ref[df_ref['time'] > '2021']

# %%
central_lon, central_lat = -71.857, -15.787
extent = [-72.86, -70.86, -14.79, -16.79]
sabancaya = (central_lon, central_lat)
ax = plt.axes(projection=ccrs.Orthographic(central_lon, central_lat))
ax.set_extent(extent)
ax.gridlines()
ax.add_feature(cfeature.LAKES, edgecolor='black')
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.RIVERS)
ax.scatter(central_lon, central_lat, marker='o', transform=ccrs.Geodetic())
ax.scatter(df_2012['longitude'], df_2012['latitude'], label='2010-2012', marker='^', transform=ccrs.Geodetic())
ax.scatter(df_2015['longitude'], df_2015['latitude'], label='2013-2015', marker='*', transform=ccrs.Geodetic())
ax.scatter(df_2018['longitude'], df_2018['latitude'], label='2016-2018', marker='*', transform=ccrs.Geodetic())
ax.scatter(df_2021['longitude'], df_2021['latitude'], label='2019-2021', marker='*', transform=ccrs.Geodetic())
ax.scatter(df_2024['longitude'], df_2024['latitude'], label='2022-2024', marker='*', transform=ccrs.Geodetic())
ax.legend()
ax.coastlines(resolution='10m')
